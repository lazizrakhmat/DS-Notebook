# %% [markdown]
# <a href="https://colab.research.google.com/github/lazizrakhmat/DS-Notebook/blob/main/data_fillna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
#
# ##3-MODUL MA'LUMOTLARGA ISHLOV BERISH
#
# ### 3.2 Ma'lumotlarni tozalash va tayyorlash
# Data Science muhandisi sifatida sizning 80% vaqtingiz ma'lumotlarga ishlov berish bilan o'tadi. Jumladan, ma'lumotlarni o'qish, kamchiliklarni bartaraf etish, ma'lumotlarni shakl o'zgartirish, matnlar bilan ishlash va hokozo.
# ### Mavjud bo'lmagan qiymatlar bilan ishlash

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df.isnull() # mavjud bo'lmagan qiymatlarga TRUE deb qaytaradi
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0        False       False       False   False        False             False
# 1        False       False        True   False        False             False
# 2        False       False       False   False        False             False
# 3        False       False       False   False        False             False
# 4        False       False       False   False        False             False
# ...        ...         ...         ...     ...          ...               ...
# 81       False       False       False   False        False             False
# 82       False       False        True   False         True             False
# 86       False       False       False    True        False             False
# 87       False       False       False   False         True             False
# 88       False       False       False   False        False             False
#
# ...

# %%
df.notnull() # yuqoridagini teskarinisi qaytaradi ya'ni FALSE
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0         True        True        True    True         True              True
# 1         True        True       False    True         True              True
# 2         True        True        True    True         True              True
# 3         True        True        True    True         True              True
# 4         True        True        True    True         True              True
# ...        ...         ...         ...     ...          ...               ...
# 81        True        True        True    True         True              True
# 82        True        True       False    True        False              True
# 86        True        True        True   False         True              True
# 87        True        True        True    True        False              True
# 88        True        True        True    True         True              True
#
# ...

# %%
df.isnull().sum() # bu True'larni umumiy soni nechtaligini hisoblaydi, ya'ni yig'inidisini aniqlaydi
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %%
len(df)
# Out:
# 61

# %%
df.isnull().sum()/len(df)*100 # % da qatorda qancha bo'sh qiymat borligini ko'rsatadi
# Out:
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %%
df.dropna() # NaN qatorlarni tashlab yuborish
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
# ...

# %%
len(df.dropna()) # NaN qiymatlar olib tashlangandan keyin qolgan soni
# Out:
# 14

# %%
df.dropna(axis=1) # ustunlar bo'yicha NaN qiymatlarni tashlab yuborish
# Out:
#            company   body-style num-of-cylinders
# index
# 0      alfa-romero  convertible             four
# 1      alfa-romero  convertible             four
# 2      alfa-romero    hatchback              six
# 3             audi        sedan             four
# 4             audi        sedan             five
# ...            ...          ...              ...
# 81      volkswagen        sedan             four
# 82      volkswagen        sedan             four
# 86      volkswagen        sedan             four
# 87           volvo        sedan             four
# 88           volvo        wagon             four
#
# [61 rows x 3 columns]

# %%
df.dropna(axis=1, thresh=48, inplace=True) # thresh=n ,chegara qo'yamiz, mavjud bo'lmagan qiymatlar, 48 tadan kam bo'lgan ustunlarni tashlab yuboramiz

# %%
df2 = df.dropna(subset=['price', 'horsepower']) # subset - Agar ana shu ustunlarda NaN qiymatlar mavjud bo'lsa o'shaq qatorni tashlab yuborgin

# %%
df.shape
# Out:
# (61, 6)

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df.fillna(999) # standart qiymat, barcha NaN qiymatlar o'rniga 0 qiymat bn to'ldirdik, lekin tavsiya qilinmaydi, faqatgina arifmetik ammallar uchun f/y
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible       999.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan       999.0   171.7         999
# 86      volkswagen        sedan        97.3   999.0         ohc
# 87           volvo        sedan       104.3   188.8         999
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       999.0             21.0  13495.0
# ...

# %%
df.fillna({'horsepower':100, "wheel-base":90}) # ustun nomini qo'yib, o'sha ustun uchun berilgan qiymat orqali to'ldirishham mumkin
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        90.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        90.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       100.0             21.0  13495.0
# ...

# %%
np.mean(df['wheel-base'])
# Out:
# 99.2195652173913

# %%
df.fillna({'horsepower':np.mean(df['horsepower']), 'wheel-base':np.mean(df['wheel-base'])}) # NaN qiymatlar o'rniga o'sha ustunning o'rtacha qiymatlari orqali to'ldirildi
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000   168.8        dohc
# 1      alfa-romero  convertible   99.219565   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 4             audi        sedan   99.400000   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan   97.300000   171.7         ohc
# 82      volkswagen        sedan   99.219565   171.7         NaN
# 86      volkswagen        sedan   97.300000     NaN         ohc
# 87           volvo        sedan  104.300000   188.8         NaN
# 88           volvo        wagon  104.300000   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.266667             21.0  13495.0
# ...

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method='ffill') # method=ffill - oldingi qiymat bilan to'ldirish
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method='bfill') # bfill - back, keyingi qiymat bilan to'ldirish
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        94.5   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   188.8         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       111.0             21.0  13495.0
# ...

# %%
df[df.company=='toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback         NaN   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         NaN             four
# 68     toyota  hatchback         NaN   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7     NaN         NaN             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67            NaN             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71            NaN             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df[df.company=='toyota'].fillna(method='bfill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df[df.company=='toyota'] = df[df.company=='toyota'].fillna(method='bfill')

# %%
df[df.company=='toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(df.mean()) # barcha ustunlarni o'rtacha qiymatlari orqali to'ldirildi
# Out:
# <ipython-input-22-b4b6c02a30ad>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean()) # barcha ustunlarni o'rtacha qiymatlari orqali to'ldirildi
#            company   body-style  wheel-base      length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000  168.800000        dohc
# 1      alfa-romero  convertible   99.072917  168.800000        dohc
# 2      alfa-romero    hatchback   94.500000  171.200000        ohcv
# 3             audi        sedan   99.800000  176.600000         ohc
# 4             audi        sedan   99.400000  176.600000         ohc
# ...            ...          ...         ...         ...         ...
# 81      volkswagen        sedan   97.300000  171.700000         ohc
# 82      volkswagen        sedan   99.072917  171.700000         NaN
# ...

# %%
dfh = df[df['body-style']=='hatchback'] # bu yerda hatchback mashinalarini chaqirib oldik

# %%
dfh
# Out:
#            company body-style  wheel-base  length engine-type  \
# index
# 2      alfa-romero  hatchback        94.5   171.2        ohcv
# 16       chevrolet  hatchback        88.4   141.1           l
# 17       chevrolet  hatchback        94.5   155.9         ohc
# 19           dodge  hatchback        93.7   157.3         ohc
# 20           dodge  hatchback        93.7     NaN         ohc
# 36           mazda  hatchback        93.1   159.1         NaN
# 37           mazda  hatchback        93.1   159.1         ohc
# 38           mazda  hatchback        93.1   159.1         ohc
# 39           mazda  hatchback         NaN     NaN         NaN
# 49      mitsubishi  hatchback         NaN   157.3         ohc
# 50      mitsubishi  hatchback        93.7     NaN         NaN
# 63         porsche  hatchback        98.4   175.7       dohcv
# 66          toyota  hatchback        95.7   158.7         ohc
# 67          toyota  hatchback        95.7   158.7         ohc
# ...

# %%
dfh.fillna(df.mean()) # aynan dfh'ga tegishli bo'lgan o'rtacha qiymati orqali to'ldirib oldik
# Out:
# <ipython-input-25-fd7ce8b0f629>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfh.fillna(df.mean()) # aynan dfh'ga tegishli bo'lgan o'rtacha qiymati orqali to'ldirib oldik
#            company body-style  wheel-base      length engine-type  \
# index
# 2      alfa-romero  hatchback   94.500000  171.200000        ohcv
# 16       chevrolet  hatchback   88.400000  141.100000           l
# 17       chevrolet  hatchback   94.500000  155.900000         ohc
# 19           dodge  hatchback   93.700000  157.300000         ohc
# 20           dodge  hatchback   93.700000  173.767347         ohc
# 36           mazda  hatchback   93.100000  159.100000         NaN
# 37           mazda  hatchback   93.100000  159.100000         ohc
# 38           mazda  hatchback   93.100000  159.100000         ohc
# ...
