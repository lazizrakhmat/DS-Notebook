# %% [markdown]
# <a href="https://colab.research.google.com/github/lazizrakhmat/DS-Notebook/blob/main/WebSahifa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web sahifalar

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
tashkentInfo =  pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
len(tashkentInfo)
# Out:
# 17

# %%
tashkentInfo[7]
# Out:
#     Year     Pop. ±% p.a.
# 0   1897   155673       —
# 1   1959   911930  +2.89%
# 2   1970  1384509  +3.87%
# 3   1979  1780002  +2.83%
# 4   1983  1902000  +1.67%
# 5   1989  2072459  +1.44%
# 6   1991  2130200  +1.38%
# 7   1995  2097400  −0.39%
# 8   2000  2142300  +0.42%
# 9   2001  2137900  −0.21%
# 10  2002  2136600  −0.06%
# 11  2003  2139200  +0.12%
# 12  2004  2135400  −0.18%
# 13  2005  2135700  +0.01%
# 14  2006  2140600  +0.23%

# %%
tashkentInfo[5]
# Out:
#    Climate data for Tashkent (1981–2010, extremes 1881–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                                Average high °C (°F)
# 2                                  Daily mean °C (°F)
# 3                                 Average low °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6                          Average precipitation days
# 7                                  Average snowy days
# 8                       Average relative humidity (%)
# 9                         Mean monthly sunshine hours
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Jan
# 0                                          22.6(72.7)
# ...

# %%
tashkentInfo[9]
# Out:
#     Nr       District  Population (2021)[1]  Area (km2)[64][63]  \
# 0    1       Bektemir                 31400               17.83
# 1    2      Chilanzar                260700               29.94
# 2    3      Yashnobod                258800               33.70
# 3    4        Mirobod                142800               17.10
# 4    5  Mirzo Ulugbek                285000               35.15
# 5    6        Sergeli                105700               37.36
# 6    7   Shayxontoxur                348300               29.70
# 7    8        Olmazor                377100               34.50
# 8    9        Uchtepa                278200               24.00
# 9   10     Yakkasaray                121600               14.60
# 10  11      Yunusabad                352000               40.60
# 11  12     Yangihayot                132800               44.20
#
#     Density (area/km2)  Map
# 0                 1761  NaN
# 1                 8707  NaN
# 2                 7680  NaN
# ...

# %% [markdown]
# ### JSON

# %%
import requests

# %%
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2015-2022")

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'key': '/subjects/python',
#  'name': 'python',
#  'subject_type': 'subject',
#  'work_count': 69,
#  'works': [{'key': '/works/OL17795703W',
#    'title': 'Python for bioinformatics',
#    'edition_count': 10,
#    'cover_id': 8078288,
#    'cover_edition_key': 'OL26385029M',
#    'subject': ['Bioinformatics',
#     'Python (computer program language)',
#     'Python (Computer program language)',
#     'Computational Biology',
#     'Bio-informatique',
#     'Python (Langage de programmation)',
#     'Programming languages (Electronic computers)',
#     'Programming Languages',
#     'Langages de programmation',
#     'COMPUTERS',
#     'Python',
#     'NATURE',
#     'Reference',
#     'SCIENCE',
#     'Life Sciences',
#     'Biology',
#     'General'],
#    'ia_collection': [''],
#    'lendinglibrary': False,
#    'printdisabled': False,
#    'lending_edition': '',
#    'lending_identifier': '',
#    'authors': [{'key': '/authors/OL3871440A', 'name': 'Sebastian Bassi'}],
# ...

# %%
pd.DataFrame(r.json())
# Out:
#                  key    name subject_type  work_count  \
# 0   /subjects/python  python      subject          69
# 1   /subjects/python  python      subject          69
# 2   /subjects/python  python      subject          69
# 3   /subjects/python  python      subject          69
# 4   /subjects/python  python      subject          69
# 5   /subjects/python  python      subject          69
# 6   /subjects/python  python      subject          69
# 7   /subjects/python  python      subject          69
# 8   /subjects/python  python      subject          69
# 9   /subjects/python  python      subject          69
# 10  /subjects/python  python      subject          69
# 11  /subjects/python  python      subject          69
#
#                                                 works
# 0   {'key': '/works/OL17795703W', 'title': 'Python...
# 1   {'key': '/works/OL6045694W', 'title': 'Python ...
# 2   {'key': '/works/OL23330617W', 'title': 'Making...
# ...

# %%
pd.DataFrame(r.json()['works'])
# Out:
#                    key                                              title  \
# 0   /works/OL17795703W                          Python for bioinformatics
# 1    /works/OL6045694W                               Python in a Nutshell
# 2   /works/OL23330617W                        Making music with computers
# 3   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 4   /works/OL21703042W                               Tour of Data Science
# 5   /works/OL19548251W                                Python for Everyone
# 6   /works/OL14940051W            Natural Language Processing With Python
# 7   /works/OL25217001W                 Introduction to Python Programming
# 8   /works/OL19932156W                                      Fluent Python
# 9   /works/OL25187574W  Introduction to Modeling and Simulation with M...
# 10  /works/OL17308344W                           Web Scraping with Python
# 11  /works/OL25347363W                      Survival Analysis with Python
#
# ...
